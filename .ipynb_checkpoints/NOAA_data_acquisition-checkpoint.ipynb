# %%
#needed to make web requests
import requests

#store the data we get as a dataframe
import pandas as pd

#convert the response as a strcuctured json
import json

#mathematical operations on lists
import numpy as np

#parse the datetimes we get from NOAA
from datetime import datetime

#add the access token you got from NOAA
Token = "KOFmXRhFqjNliHASNkTQCsPltvHnfMuq"

#Long Beach Airport station
station_id = 'GHCND:USW00023129'

#https://www.ncdc.noaa.gov/cdo-web/api/v2/locations?locationcategoryid=ST&limit=52
#https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TMIN&limit=1000&stationid=GHCND:USW00023129&startdate='+year+'-01-01&enddate='+year+'-12-31', headers={'token':Token})

# %%
#initialize lists to store data
dates_temp = []
dates_prcp = []
temps = []
prcp = []

#for each year from 2015-2019 ...
for year in range(2015, 2020):
    year = str(year)
    print('working on year '+year)
  
    #make the api call
    r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TMIN&limit=1000&stationid=GHCND:USW00023129&startdate='+year+'-01-01&enddate='+year+'-12-31', headers={'token':Token})
    #load the api response as a json
    d = json.loads(r.text)
    #get all items in the response which are average temperature readings
    avg_temps = [item for item in d['results'] if item['datatype']=='TMIN']
    #get the date field from all average temperature readings
    dates_temp += [item['date'] for item in avg_temps]
    #get the actual average temperature from all average temperature readings
    temps += [item['value'] for item in avg_temps]
# Out:
# working on year 2015
# working on year 2016
# working on year 2017
# working on year 2018
# working on year 2019

# %%
d["results"]
# Out:
# [{'date': '2019-01-01T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 78},
#  {'date': '2019-01-02T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 33},
#  {'date': '2019-01-03T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 56},
#  {'date': '2019-01-04T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 50},
#  {'date': '2019-01-05T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 94},
#  {'date': '2019-01-06T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 89},
#  {'date': '2019-01-07T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 111},
#  {'date': '2019-01-08T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 94},
#  {'date': '2019-01-09T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 89},
#  {'date': '2019-01-10T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 89},
#  {'date': '2019-01-11T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 117},
#  {'date': '2019-01-12T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 100},
#  {'date': '2019-01-13T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 72},
#  {'date': '2019-01-14T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 111},
#  {'date': '2019-01-15T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 100},
#  {'date': '2019-01-16T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 128},
#  {'date': '2019-01-17T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 133},
#  {'date': '2019-01-18T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 117},
#  {'date': '2019-01-19T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 94},
#  {'date': '2019-01-20T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 111},
#  {'date': '2019-01-21T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 106},
#  {'date': '2019-01-22T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 61},
#  {'date': '2019-01-23T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 61},
#  {'date': '2019-01-24T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 78},
#  {'date': '2019-01-25T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 83},
#  {'date': '2019-01-26T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 94},
#  {'date': '2019-01-27T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 94},
#  {'date': '2019-01-28T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 89},
#  {'date': '2019-01-29T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 117},
#  {'date': '2019-01-30T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 122},
#  {'date': '2019-01-31T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 106},
#  {'date': '2019-02-01T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 89},
#  {'date': '2019-02-02T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 100},
#  {'date': '2019-02-03T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 100},
#  {'date': '2019-02-04T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 111},
#  {'date': '2019-02-05T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 83},
#  {'date': '2019-02-06T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 44},
#  {'date': '2019-02-07T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 44},
#  {'date': '2019-02-08T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 44},
#  {'date': '2019-02-09T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 72},
#  {'date': '2019-02-10T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 78},
#  {'date': '2019-02-11T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 33},
#  {'date': '2019-02-12T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 33},
#  {'date': '2019-02-13T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 106},
#  {'date': '2019-02-14T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 117},
#  {'date': '2019-02-15T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 94},
#  {'date': '2019-02-16T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 89},
#  {'date': '2019-02-17T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 61},
#  {'date': '2019-02-18T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 39},
#  {'date': '2019-02-19T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 28},
#  {'date': '2019-02-20T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 44},
#  {'date': '2019-02-21T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 56},
#  {'date': '2019-02-22T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 28},
#  {'date': '2019-02-23T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 56},
#  {'date': '2019-02-24T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 72},
#  {'date': '2019-02-25T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 83},
#  {'date': '2019-02-26T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 83},
#  {'date': '2019-02-27T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 111},
#  {'date': '2019-02-28T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 133},
#  {'date': '2019-03-01T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-03-02T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 133},
#  {'date': '2019-03-03T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 133},
#  {'date': '2019-03-04T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 111},
#  {'date': '2019-03-05T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 89},
#  {'date': '2019-03-06T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 133},
#  {'date': '2019-03-07T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 111},
#  {'date': '2019-03-08T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 94},
#  {'date': '2019-03-09T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 89},
#  {'date': '2019-03-10T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 89},
#  {'date': '2019-03-11T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 89},
#  {'date': '2019-03-12T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 117},
#  {'date': '2019-03-13T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 100},
#  {'date': '2019-03-14T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 83},
#  {'date': '2019-03-15T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 83},
#  {'date': '2019-03-16T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 100},
#  {'date': '2019-03-17T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 122},
#  {'date': '2019-03-18T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 128},
#  {'date': '2019-03-19T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 122},
#  {'date': '2019-03-20T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 133},
#  {'date': '2019-03-21T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 111},
#  {'date': '2019-03-22T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 94},
#  {'date': '2019-03-23T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 122},
#  {'date': '2019-03-24T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 122},
#  {'date': '2019-03-25T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 106},
#  {'date': '2019-03-26T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 100},
#  {'date': '2019-03-27T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 133},
#  {'date': '2019-03-28T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 128},
#  {'date': '2019-03-29T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 111},
#  {'date': '2019-03-30T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 111},
#  {'date': '2019-03-31T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 122},
#  {'date': '2019-04-01T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 150},
#  {'date': '2019-04-02T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 150},
#  {'date': '2019-04-03T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 139},
#  {'date': '2019-04-04T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 139},
#  {'date': '2019-04-05T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 139},
#  {'date': '2019-04-06T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-04-07T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 139},
#  {'date': '2019-04-08T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 156},
#  {'date': '2019-04-09T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 156},
#  {'date': '2019-04-10T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-04-11T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 111},
#  {'date': '2019-04-12T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 117},
#  {'date': '2019-04-13T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 128},
#  {'date': '2019-04-14T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 122},
#  {'date': '2019-04-15T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 117},
#  {'date': '2019-04-16T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 139},
#  {'date': '2019-04-17T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 117},
#  {'date': '2019-04-18T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 128},
#  {'date': '2019-04-19T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 139},
#  {'date': '2019-04-20T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-04-21T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 133},
#  {'date': '2019-04-22T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 117},
#  {'date': '2019-04-23T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 139},
#  {'date': '2019-04-24T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-04-25T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-04-26T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-04-27T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 150},
#  {'date': '2019-04-28T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 150},
#  {'date': '2019-04-29T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 139},
#  {'date': '2019-04-30T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-05-01T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 117},
#  {'date': '2019-05-02T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 133},
#  {'date': '2019-05-03T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-05-04T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 156},
#  {'date': '2019-05-05T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 156},
#  {'date': '2019-05-06T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 150},
#  {'date': '2019-05-07T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-05-08T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 161},
#  {'date': '2019-05-09T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 161},
#  {'date': '2019-05-10T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 156},
#  {'date': '2019-05-11T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-05-12T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 156},
#  {'date': '2019-05-13T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 167},
#  {'date': '2019-05-14T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 161},
#  {'date': '2019-05-15T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 167},
#  {'date': '2019-05-16T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 139},
#  {'date': '2019-05-17T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 122},
#  {'date': '2019-05-18T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 128},
#  {'date': '2019-05-19T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 117},
#  {'date': '2019-05-20T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 139},
#  {'date': '2019-05-21T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-05-22T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 133},
#  {'date': '2019-05-23T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-05-24T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 128},
#  {'date': '2019-05-25T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 133},
#  {'date': '2019-05-26T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 139},
#  {'date': '2019-05-27T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 106},
#  {'date': '2019-05-28T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 122},
#  {'date': '2019-05-29T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 150},
#  {'date': '2019-05-30T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-05-31T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-06-01T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 156},
#  {'date': '2019-06-02T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 156},
#  {'date': '2019-06-03T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 156},
#  {'date': '2019-06-04T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 156},
#  {'date': '2019-06-05T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 156},
#  {'date': '2019-06-06T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 161},
#  {'date': '2019-06-07T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 161},
#  {'date': '2019-06-08T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 167},
#  {'date': '2019-06-09T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 167},
#  {'date': '2019-06-10T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 167},
#  {'date': '2019-06-11T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-06-12T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 172},
#  {'date': '2019-06-13T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 167},
#  {'date': '2019-06-14T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 167},
#  {'date': '2019-06-15T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-06-16T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-06-17T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 172},
#  {'date': '2019-06-18T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 167},
#  {'date': '2019-06-19T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-06-20T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 172},
#  {'date': '2019-06-21T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 161},
#  {'date': '2019-06-22T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 172},
#  {'date': '2019-06-23T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 172},
#  {'date': '2019-06-24T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 167},
#  {'date': '2019-06-25T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 172},
#  {'date': '2019-06-26T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-06-27T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-06-28T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-06-29T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 167},
#  {'date': '2019-06-30T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-07-01T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 172},
#  {'date': '2019-07-02T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-07-03T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-07-04T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-07-05T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-07-06T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-07-07T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-07-08T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-07-09T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-07-10T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-07-11T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-07-12T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 189},
#  {'date': '2019-07-13T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-07-14T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-07-15T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-07-16T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-07-17T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 200},
#  {'date': '2019-07-18T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-07-19T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-07-20T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 194},
#  {'date': '2019-07-21T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-07-22T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 189},
#  {'date': '2019-07-23T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 211},
#  {'date': '2019-07-24T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 228},
#  {'date': '2019-07-25T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 228},
#  {'date': '2019-07-26T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 222},
#  {'date': '2019-07-27T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 211},
#  {'date': '2019-07-28T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 194},
#  {'date': '2019-07-29T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 194},
#  {'date': '2019-07-30T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 200},
#  {'date': '2019-07-31T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 200},
#  {'date': '2019-08-01T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 189},
#  {'date': '2019-08-02T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 189},
#  {'date': '2019-08-03T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 200},
#  {'date': '2019-08-04T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 194},
#  {'date': '2019-08-05T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 189},
#  {'date': '2019-08-06T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 194},
#  {'date': '2019-08-07T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 194},
#  {'date': '2019-08-08T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 189},
#  {'date': '2019-08-09T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-08-10T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-08-11T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-08-12T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-08-13T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-08-14T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-08-15T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-08-16T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-08-17T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 189},
#  {'date': '2019-08-18T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 194},
#  {'date': '2019-08-19T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 189},
#  {'date': '2019-08-20T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-08-21T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-08-22T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 200},
#  {'date': '2019-08-23T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 206},
#  {'date': '2019-08-24T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 200},
#  {'date': '2019-08-25T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 206},
#  {'date': '2019-08-26T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 211},
#  {'date': '2019-08-27T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 211},
#  {'date': '2019-08-28T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 217},
#  {'date': '2019-08-29T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 211},
#  {'date': '2019-08-30T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 217},
#  {'date': '2019-08-31T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 206},
#  {'date': '2019-09-01T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 194},
#  {'date': '2019-09-02T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 211},
#  {'date': '2019-09-03T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 233},
#  {'date': '2019-09-04T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 233},
#  {'date': '2019-09-05T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 228},
#  {'date': '2019-09-06T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 222},
#  {'date': '2019-09-07T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 206},
#  {'date': '2019-09-08T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-09-09T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 194},
#  {'date': '2019-09-10T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 200},
#  {'date': '2019-09-11T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 194},
#  {'date': '2019-09-12T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 194},
#  {'date': '2019-09-13T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 200},
#  {'date': '2019-09-14T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 200},
#  {'date': '2019-09-15T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 200},
#  {'date': '2019-09-16T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 200},
#  {'date': '2019-09-17T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 194},
#  {'date': '2019-09-18T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-09-19T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 194},
#  {'date': '2019-09-20T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 189},
#  {'date': '2019-09-21T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-09-22T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 194},
#  {'date': '2019-09-23T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 194},
#  {'date': '2019-09-24T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 183},
#  {'date': '2019-09-25T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 206},
#  {'date': '2019-09-26T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 217},
#  {'date': '2019-09-27T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 206},
#  {'date': '2019-09-28T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 189},
#  {'date': '2019-09-29T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 156},
#  {'date': '2019-09-30T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 139},
#  {'date': '2019-10-01T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 139},
#  {'date': '2019-10-02T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-10-03T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-10-04T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 139},
#  {'date': '2019-10-05T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-10-06T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-10-07T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 156},
#  {'date': '2019-10-08T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 150},
#  {'date': '2019-10-09T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 172},
#  {'date': '2019-10-10T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 189},
#  {'date': '2019-10-11T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 139},
#  {'date': '2019-10-12T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-10-13T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 139},
#  {'date': '2019-10-14T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 161},
#  {'date': '2019-10-15T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-10-16T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 156},
#  {'date': '2019-10-17T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 178},
#  {'date': '2019-10-18T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 156},
#  {'date': '2019-10-19T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 139},
#  {'date': '2019-10-20T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 150},
#  {'date': '2019-10-21T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 167},
#  {'date': '2019-10-22T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 161},
#  {'date': '2019-10-23T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 161},
#  {'date': '2019-10-24T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 156},
#  {'date': '2019-10-25T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 189},
#  {'date': '2019-10-26T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 156},
#  {'date': '2019-10-27T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 161},
#  {'date': '2019-10-28T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 122},
#  {'date': '2019-10-29T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 117},
#  {'date': '2019-10-30T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 117},
#  {'date': '2019-10-31T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 100},
#  {'date': '2019-11-01T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 100},
#  {'date': '2019-11-02T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 100},
#  {'date': '2019-11-03T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 100},
#  {'date': '2019-11-04T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 100},
#  {'date': '2019-11-05T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 106},
#  {'date': '2019-11-06T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 122},
#  {'date': '2019-11-07T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 133},
#  {'date': '2019-11-08T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 117},
#  {'date': '2019-11-09T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 122},
#  {'date': '2019-11-10T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 150},
#  {'date': '2019-11-11T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-11-12T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-11-13T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 139},
#  {'date': '2019-11-14T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 122},
#  {'date': '2019-11-15T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 122},
#  {'date': '2019-11-16T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 106},
#  {'date': '2019-11-17T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 117},
#  {'date': '2019-11-18T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 133},
#  {'date': '2019-11-19T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 144},
#  {'date': '2019-11-20T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 111},
#  {'date': '2019-11-21T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 106},
#  {'date': '2019-11-22T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 100},
#  {'date': '2019-11-23T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 117},
#  {'date': '2019-11-24T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 111},
#  {'date': '2019-11-25T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 83},
#  {'date': '2019-11-26T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 94},
#  {'date': '2019-11-27T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 100},
#  {'date': '2019-11-28T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 72},
#  {'date': '2019-11-29T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 50},
#  {'date': '2019-11-30T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 61},
#  {'date': '2019-12-01T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 94},
#  {'date': '2019-12-02T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 78},
#  {'date': '2019-12-03T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 106},
#  {'date': '2019-12-04T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,W,2400',
#   'value': 117},
#  {'date': '2019-12-05T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 94},
#  {'date': '2019-12-06T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 100},
#  {'date': '2019-12-07T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 150},
#  {'date': '2019-12-08T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 133},
#  {'date': '2019-12-09T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 100},
#  {'date': '2019-12-10T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 89},
#  {'date': '2019-12-11T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 78},
#  {'date': '2019-12-12T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 100},
#  {'date': '2019-12-13T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 100},
#  {'date': '2019-12-14T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 106},
#  {'date': '2019-12-15T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 83},
#  {'date': '2019-12-16T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 61},
#  {'date': '2019-12-17T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 56},
#  {'date': '2019-12-18T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 39},
#  {'date': '2019-12-19T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 44},
#  {'date': '2019-12-20T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 72},
#  {'date': '2019-12-21T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 83},
#  {'date': '2019-12-22T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 89},
#  {'date': '2019-12-23T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 89},
#  {'date': '2019-12-24T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 67},
#  {'date': '2019-12-25T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 61},
#  {'date': '2019-12-26T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 72},
#  {'date': '2019-12-27T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 44},
#  {'date': '2019-12-28T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 56},
#  {'date': '2019-12-29T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 61},
#  {'date': '2019-12-30T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 94},
#  {'date': '2019-12-31T00:00:00',
#   'datatype': 'TMIN',
#   'station': 'GHCND:USW00023129',
#   'attributes': ',,D,2400',
#   'value': 78}]

# %%
#initialize dataframe
df_temp = pd.DataFrame()

#populate date and average temperature fields (cast string date to datetime and convert temperature from tenths of Celsius to Fahrenheit)
df_temp['date'] = [datetime.strptime(d, "%Y-%m-%dT%H:%M:%S") for d in dates_temp]
df_temp['avgTemp'] = [float(v)/10.0 for v in temps]

# %%
df_temp.tail()
# Out:
#            date  avgTemp
# 1821 2019-12-27      4.4
# 1822 2019-12-28      5.6
# 1823 2019-12-29      6.1
# 1824 2019-12-30      9.4
# 1825 2019-12-31      7.8

# %%
import pandas as pd

# %%
url = "https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/ghcnd-stations.txt"

# %%
df = pd.read_csv(url, sep='\t', header = None)

# %%
df.rename(columns={0: "weather_station"}, inplace = True)

# %%
df[['station_id','latitude',"longitude", "elevation", "state", "city", "description"]] = df.weather_station.str.split( n = 6, expand = True)

# %%
df.columns
# Out:
# Index(['weather_station', 'station_id', 'latitude', 'longitude', 'elevation',
#        'state', 'city', 'description'],
#       dtype='object')

# %%
#united_states1 = df[df["station_id"].str.match('US1')]


#united_states2 = df[df["station_id"].str.match('USC')]
united_states3 = df[df["station_id"].str.match('USR')]
united_states4 = df[df["station_id"].str.match('USS')]
united_states5 = df[df["station_id"].str.match('USW')]

# %%
united_state_ws = pd.concat([ united_states2, united_states3, united_states5, united_states5], ignore_index= True)

# %%
united_state_ws.drop(columns=["weather_station"], inplace = True)

# %%
united_state_ws.groupby(["state"]).count()
# Out:
#        station_id  latitude  longitude  elevation  city  description
# state
# AK            991       991        991        991   991          820
# AL            446       446        446        446   446          298
# AR            394       394        394        394   394          264
# AZ            672       672        672        672   672          556
# CA           1781      1781       1781       1781  1781         1543
# CO            708       708        708        708   708          562
# CT            132       132        132        132   132           93
# DC              3         3          3          3     3            0
# DE             28        28         28         28    28           22
# FL            507       507        507        507   507          420
# GA            474       474        474        474   474          316
# HI            661       661        661        661   661          625
# IA            439       439        439        439   439          273
# ID            532       532        532        532   532          376
# IL            571       571        571        571   571          388
# IN            419       419        419        419   419          312
# KS            695       695        695        695   695          440
# KY            485       485        485        485   485          329
# LA            517       517        517        517   517          362
# MA            333       333        333        333   333          196
# MD            262       262        262        262   262          193
# ME            261       261        261        261   261          167
# MI            688       688        688        688   688          492
# MN            495       495        495        495   495          367
# MO            615       615        615        615   615          400
# MS            369       369        369        369   369          244
# MT            865       865        865        865   865          634
# NC            586       586        586        586   586          441
# ND            339       339        339        339   339          217
# NE            590       590        590        590   590          375
# NH            236       236        236        236   236          151
# NJ            186       186        186        186   186          126
# NM            763       763        763        763   763          545
# NV            440       440        440        440   440          328
# NY            878       878        878        878   878          588
# OH            571       571        571        571   571          403
# OK            548       548        548        548   548          394
# OR            872       872        872        872   872          641
# PA            775       775        775        775   775          551
# PI              1         1          1          1     1            1
# RI             52        52         52         52    52           39
# SC            270       270        270        270   270          216
# SD            433       433        433        433   433          302
# TN            558       558        558        558   558          375
# TX           1739      1739       1739       1739  1739         1173
# UM              2         2          2          2     2            2
# UT            622       622        622        622   622          463
# VA            488       488        488        488   488          332
# VT            172       172        172        172   172          112
# WA            649       649        649        649   649          486
# WI            455       455        455        455   455          315
# WV            402       402        402        402   402          251
# WY            523       523        523        523   523          412

# %%
united_state_ws.shape
# Out:
# (27493, 7)

# %%
co = united_state_ws[united_state_ws['state']=="CO"].sample(n=50)

# %%
station_ids = ['GHCND:'+ stations for stations in co["station_id"]]
state = [state for state in co["state"]]
len(state)
# Out:
# 50

# %%
(state[0])
# Out:
# 'CO'

# %%
#initialize lists to store data
dates_temp = []
dates_prcp = []
temps = []
prcp = []
states =[]
year = '2015'
min_temps = []
#for each year from 2015-2019 ...
#for year in range(2015, 2020):
#    year = str(year)
#for id in station_ids:

# %%
#make the api call
for idx, id in enumerate(station_ids):
    
    
    r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TMIN&limit=1000&stationid='+id+'&startdate='+year+'-01-01&enddate='+year+'-12-31', headers={'token':Token})
    #r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TMIN&limit=1000&stationid=GHCND:USC00051978&startdate='+year+'-01-01&enddate='+year+'-12-31', headers={'token':Token})
    #load the api response as a json
    d = json.loads(r.text)
    
    #get all items in the response which are minimum temperature readings
    if (bool(d)):
        min_temps.append([item for item in d['results'] if item['datatype']=='TMIN'])
#get the date field from all average temperature readings


    #get the date field from all average temperature readings
        dates_temp.append([((other["date"])) for item in min_temps for other in item])
    #get the actual minimum temperature from all minimum temperature readings
        temps.append( [item['value'] for items in min_temps for item in items] )
        states.append(state[idx])



os.system('afplay /System/Library/Sounds/Blow.aiff')
# Out:
# 0

# %%
type(dates_temp[0])
# len(min_temps)
# len(temps)
# len(states)
# Out:
# list

# %%
len(temps)
len(temps[0])
# Out:
# 363

# %%
#flatten list of lists
dates = [item for sublist in dates_temp for item in sublist]
temperature = [item for sublist in temps for item in sublist]
state = [item for sublist in states for item in sublist]

# %%
#get the actual minimum temperature from all minimum temperature readings
temps += [item['value'] for items in min_temps for item in items] 
len(temps)
# Out:
# []

# %%
#initialize dataframe
df_temp = pd.DataFrame()

#populate date and average temperature fields (cast string date to datetime and convert temperature from tenths of Celsius to Fahrenheit)
df_temp['date'] = [datetime.strptime(d, "%Y-%m-%dT%H:%M:%S") for d in dates_temp]
df_temp['avgTemp'] = [float(v)/10.0 for v in temps]
df_temp['state'] = [state for state in states]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-290-7ece0237afc8> in <module>
#       4 #populate date and average temperature fields (cast string date to datetime and convert temperature from tenths of Celsius to Fahrenheit)
#       5 df_temp['date'] = [datetime.strptime(d, "%Y-%m-%dT%H:%M:%S") for d in dates_temp]
# ----> 6 df_temp['avgTemp'] = [float(v)/10.0 for v in temps]
#       7 df_temp['state'] = [state for state in states]
#
# <ipython-input-290-7ece0237afc8> in <listcomp>(.0)
#       4 #populate date and average temperature fields (cast string date to datetime and convert temperature from tenths of Celsius to Fahrenheit)
#       5 df_temp['date'] = [datetime.strptime(d, "%Y-%m-%dT%H:%M:%S") for d in dates_temp]
# ----> 6 df_temp['avgTemp'] = [float(v)/10.0 for v in temps]
#       7 df_temp['state'] = [state for state in states]
#
# TypeError: float() argument must be a string or a number, not 'list'

# %%
df_temp.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
crime = pd.read_csv("/Users/GuntherUlvanget/Capstone/Capstone2/Arrest_Data_from_2010_to_Present.csv")

# %%
crime.groupby("Charge Group Description").count()
# Out:
#                                 Report ID  Arrest Date    Time  Area ID  \
# Charge Group Description
# Against Family/Child                 7530         7530    7530     7530
# Aggravated Assault                  87707        87707   87707    87707
# Burglary                            24661        24661   24661    24661
# Disorderly Conduct                  37156        37156   37148    37156
# Disturbing the Peace                 2972         2972    2971     2972
# Driving Under Influence            121981       121981  121981   121981
# Drunkeness                         116071       116071  116024   116071
# Federal Offenses                      241          241     241      241
# Forgery/Counterfeit                  7027         7027    7027     7027
# Fraud/Embezzlement                   9756         9756    9756     9756
# Gambling                             2415         2415    2415     2415
# Homicide                             2493         2493    2493     2493
# Larceny                             71436        71436   71433    71436
# Liquor Laws                         52132        52132   52105    52132
# Miscellaneous Other Violations     245827       245827  245790   245827
# Moving Traffic Violations           53881        53881   53881    53881
# Narcotic Drug Laws                 164708       164708  164703   164708
# Non-Criminal Detention               6933         6933    6933     6933
# Other Assaults                      64627        64627   64627    64627
# Pre-Delinquency                     11901        11901   11896    11901
# Prostitution/Allied                 39908        39908   39903    39908
# Rape                                 3038         3038    3036     3038
# Receive Stolen Property              6757         6757    6757     6757
# Robbery                             27270        27270   27270    27270
# Sex (except rape/prst)              13598        13598   13598    13598
# Vehicle Theft                       25622        25622   25622    25622
# Weapon (carry/poss)                 31730        31730   31730    31730
#
#                                 Area Name  Reporting District     Age  \
# Charge Group Description
# Against Family/Child                 7530                7530    7530
# Aggravated Assault                  87707               87707   87707
# Burglary                            24661               24661   24661
# Disorderly Conduct                  37156               37156   37156
# Disturbing the Peace                 2972                2972    2972
# Driving Under Influence            121981              121981  121981
# Drunkeness                         116071              116071  116071
# Federal Offenses                      241                 241     241
# Forgery/Counterfeit                  7027                7027    7027
# Fraud/Embezzlement                   9756                9756    9756
# Gambling                             2415                2415    2415
# Homicide                             2493                2493    2493
# Larceny                             71436               71436   71436
# Liquor Laws                         52132               52132   52132
# Miscellaneous Other Violations     245827              245827  245827
# Moving Traffic Violations           53881               53881   53881
# Narcotic Drug Laws                 164708              164708  164708
# Non-Criminal Detention               6933                6933    6933
# Other Assaults                      64627               64627   64627
# Pre-Delinquency                     11901               11901   11901
# Prostitution/Allied                 39908               39908   39908
# Rape                                 3038                3038    3038
# Receive Stolen Property              6757                6757    6757
# Robbery                             27270               27270   27270
# Sex (except rape/prst)              13598               13598   13598
# Vehicle Theft                       25622               25622   25622
# Weapon (carry/poss)                 31730               31730   31730
#
#                                 Sex Code  Descent Code  Charge Group Code  \
# Charge Group Description
# Against Family/Child                7530          7530               7530
# Aggravated Assault                 87707         87707              87707
# Burglary                           24661         24661              24661
# Disorderly Conduct                 37156         37156              37156
# Disturbing the Peace                2972          2972               2972
# Driving Under Influence           121981        121981             121981
# Drunkeness                        116071        116071             116071
# Federal Offenses                     241           241                241
# Forgery/Counterfeit                 7027          7027               7027
# Fraud/Embezzlement                  9756          9756               9756
# Gambling                            2415          2415               2415
# Homicide                            2493          2493               2493
# Larceny                            71436         71436              71436
# Liquor Laws                        52132         52132              52132
# Miscellaneous Other Violations    245827        245827             245827
# Moving Traffic Violations          53881         53881              53881
# Narcotic Drug Laws                164708        164708             164708
# Non-Criminal Detention              6933          6933               6933
# Other Assaults                     64627         64627              64627
# Pre-Delinquency                    11901         11901              11901
# Prostitution/Allied                39908         39908              39908
# Rape                                3038          3038               3038
# Receive Stolen Property             6757          6757               6757
# Robbery                            27270         27270              27270
# Sex (except rape/prst)             13598         13598              13598
# Vehicle Theft                      25622         25622              25622
# Weapon (carry/poss)                31730         31730              31730
#
#                                 Arrest Type Code  Charge  Charge Description  \
# Charge Group Description
# Against Family/Child                        7530    7530                7530
# Aggravated Assault                         87707   87707               87707
# Burglary                                   24661   24661               24661
# Disorderly Conduct                         37156   37156               37156
# Disturbing the Peace                        2972    2972                2972
# Driving Under Influence                   121981  121981              121981
# Drunkeness                                116071  116071              116071
# Federal Offenses                             241     241                 241
# Forgery/Counterfeit                         7027    7027                7027
# Fraud/Embezzlement                          9756    9756                9756
# Gambling                                    2415    2415                2415
# Homicide                                    2493    2493                2493
# Larceny                                    71436   71436               71436
# Liquor Laws                                52132   52132               52132
# Miscellaneous Other Violations            245827  245827              245827
# Moving Traffic Violations                  53881   53881               53881
# Narcotic Drug Laws                        164708  164708              164708
# Non-Criminal Detention                      6933    6933                6933
# Other Assaults                             64627   64627               64627
# Pre-Delinquency                            11901   11901               11901
# Prostitution/Allied                        39908   39908               39908
# Rape                                        3038    3038                3038
# Receive Stolen Property                     6757    6757                6757
# Robbery                                    27270   27270               27270
# Sex (except rape/prst)                     13598   13598               13598
# Vehicle Theft                              25622   25622               25622
# Weapon (carry/poss)                        31730   31730               31730
#
#                                 Address  Cross Street  Location
# Charge Group Description
# Against Family/Child               7530          1294      7530
# Aggravated Assault                87707         21675     87707
# Burglary                          24661          8431     24661
# Disorderly Conduct                37156         28888     37156
# Disturbing the Peace               2972           593      2972
# Driving Under Influence          121981        104238    121981
# Drunkeness                       116071         84558    116071
# Federal Offenses                    241           135       241
# Forgery/Counterfeit                7027          2927      7027
# Fraud/Embezzlement                 9756          4049      9756
# Gambling                           2415           871      2415
# Homicide                           2493           795      2493
# Larceny                           71436         11763     71436
# Liquor Laws                       52132         37106     52132
# Miscellaneous Other Violations   245827        138993    245827
# Moving Traffic Violations         53881         35511     53881
# Narcotic Drug Laws               164708        103898    164708
# Non-Criminal Detention             6933           478      6933
# Other Assaults                    64627         18235     64627
# Pre-Delinquency                   11901          9478     11901
# Prostitution/Allied               39908         30258     39908
# Rape                               3038           545      3038
# Receive Stolen Property            6757          3354      6757
# Robbery                           27270         13966     27270
# Sex (except rape/prst)            13598          4705     13598
# Vehicle Theft                     25622         17045     25622
# Weapon (carry/poss)               31730         16327     31730

# %%
import os
#duration = 1  # seconds
#freq = 440  # Hz
os.system('afplay /System/Library/Sounds/Blow.aiff')
# Out:
# 0
