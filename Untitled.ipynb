# %%
! pip install delphi-epidata

# %%
# Import
from delphi_epidata import Epidata
# Fetch data
res = Epidata.fluview(['cen9'], [201440, Epidata.range(201501, 201510)])
res
# Out:
# {'result': 1,
#  'epidata': [{'release_date': '2017-10-24',
#    'region': 'cen9',
#    'issue': 201740,
#    'epiweek': 201440,
#    'lag': 157,
#    'num_ili': 996,
#    'num_patients': 54871,
#    'num_providers': 195,
#    'num_age_0': 254,
#    'num_age_1': 469,
#    'num_age_2': None,
#    'num_age_3': 163,
#    'num_age_4': 66,
#    'num_age_5': 44,
#    'wili': 1.6396,
#    'ili': 1.81517},
#   {'release_date': '2017-10-24',
#    'region': 'cen9',
#    'issue': 201740,
#    'epiweek': 201501,
#    'lag': 143,
#    'num_ili': 2432,
#    'num_patients': 59046,
#    'num_providers': 242,
#    'num_age_0': 550,
#    'num_age_1': 929,
#    'num_age_2': None,
#    'num_age_3': 490,
#    'num_age_4': 259,
#    'num_age_5': 204,
#    'wili': 3.93495,
#    'ili': 4.11882},
#   {'release_date': '2017-10-24',
#    'region': 'cen9',
#    'issue': 201740,
#    'epiweek': 201502,
#    'lag': 142,
#    'num_ili': 2814,
#    'num_patients': 60696,
#    'num_providers': 235,
# ...

# %%
print(res['result'], res['message'], len(res['epidata']))
# Out:
# 1 success 11

# %%
res
# Out:
# {'result': 1,
#  'epidata': [{'release_date': '2017-10-24',
#    'region': 'nat',
#    'issue': 201740,
#    'epiweek': 201440,
#    'lag': 157,
#    'num_ili': 10150,
#    'num_patients': 841540,
#    'num_providers': 1937,
#    'num_age_0': 2958,
#    'num_age_1': 3994,
#    'num_age_2': None,
#    'num_age_3': 1959,
#    'num_age_4': 712,
#    'num_age_5': 527,
#    'wili': 1.16191,
#    'ili': 1.20612},
#   {'release_date': '2017-10-24',
#    'region': 'nat',
#    'issue': 201740,
#    'epiweek': 201501,
#    'lag': 143,
#    'num_ili': 31483,
#    'num_patients': 771835,
#    'num_providers': 1958,
#    'num_age_0': 7160,
#    'num_age_1': 9589,
#    'num_age_2': None,
#    'num_age_3': 8072,
#    'num_age_4': 3614,
#    'num_age_5': 3048,
#    'wili': 4.21374,
#    'ili': 4.07898},
#   {'release_date': '2017-10-24',
#    'region': 'nat',
#    'issue': 201740,
#    'epiweek': 201502,
#    'lag': 142,
#    'num_ili': 31204,
#    'num_patients': 792459,
# ...

# %%
Epidata.fluview_clinical()
# Out:
# {'result': 1,
#  'epidata': [{'release_date': '2017-10-24',
#    'region': 'nat',
#    'issue': 201740,
#    'epiweek': 201440,
#    'lag': 157,
#    'num_ili': 10150,
#    'num_patients': 841540,
#    'num_providers': 1937,
#    'num_age_0': 2958,
#    'num_age_1': 3994,
#    'num_age_2': None,
#    'num_age_3': 1959,
#    'num_age_4': 712,
#    'num_age_5': 527,
#    'wili': 1.16191,
#    'ili': 1.20612},
#   {'release_date': '2017-10-24',
#    'region': 'nat',
#    'issue': 201740,
#    'epiweek': 201501,
#    'lag': 143,
#    'num_ili': 31483,
#    'num_patients': 771835,
#    'num_providers': 1958,
#    'num_age_0': 7160,
#    'num_age_1': 9589,
#    'num_age_2': None,
#    'num_age_3': 8072,
#    'num_age_4': 3614,
#    'num_age_5': 3048,
#    'wili': 4.21374,
#    'ili': 4.07898},
#   {'release_date': '2017-10-24',
#    'region': 'nat',
#    'issue': 201740,
#    'epiweek': 201502,
#    'lag': 142,
#    'num_ili': 31204,
#    'num_patients': 792459,
# ...
